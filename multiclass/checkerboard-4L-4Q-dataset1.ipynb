# %% [markdown]
# # Imports

# %%
import math
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import json
import os
from datetime import datetime

# %%
from qiskit                 import QuantumCircuit, QuantumRegister, ClassicalRegister, transpile
from qiskit.circuit.library import ZZFeatureMap, TwoLocal, XGate
from qiskit.quantum_info    import partial_trace
from qiskit.visualization   import plot_histogram

# %%
from qiskit_aer                         import AerSimulator
from qiskit_machine_learning.optimizers import SPSA

# %% [markdown]
# # Read Data

# %%
# Dataset configuration
DATASET_NUM = "1"
RESULTS_DIR = f"results/checkerboard-4L-4Q-dataset{DATASET_NUM}"
os.makedirs(RESULTS_DIR, exist_ok=True)

print(f"Training on Dataset {DATASET_NUM} with SPSA")
print(f"Results will be saved to: {RESULTS_DIR}")
# Out:
# Training on Dataset 1 with SPSA
# Results will be saved to: results/checkerboard-4L-4Q-dataset1

# %%
train_data   = pd.read_csv(f'datasets/dataset{DATASET_NUM}/train_data').to_numpy()
train_labels = pd.read_csv(f'datasets/dataset{DATASET_NUM}/train_labels').to_numpy().flatten()
test_data    = pd.read_csv(f'datasets/dataset{DATASET_NUM}/test_data').to_numpy()
test_labels  = pd.read_csv(f'datasets/dataset{DATASET_NUM}/test_labels').to_numpy().flatten()

print(f"Training data shape: {train_data.shape}")
print(f"Training labels shape: {train_labels.shape}")
print(f"Test data shape: {test_data.shape}")
print(f"Test labels shape: {test_labels.shape}")
# Out:
# Training data shape: (128, 2)
# Training labels shape: (128,)
# Test data shape: (64, 2)
# Test labels shape: (64,)

# %% [markdown]
# # Global Parameres

# %%
num_reupload   = 2
num_register   = int(np.log2(len(train_data)))
num_features   = len(train_data[0])
num_parameters = num_reupload*TwoLocal(2*num_features, ['ry','rz'], 'cz', 'full', reps=1).num_parameters
initial_point  = np.random.uniform(-np.pi, np.pi, size=num_parameters)

# %% [markdown]
# # Encoder and Variatinal Circuits

# %%
ZZFeatureMap(feature_dimension = num_features).draw('mpl')

# %%
TwoLocal(4, ['ry','rz'], 'cz', 'full', reps=1, insert_barriers=True, flatten=True).draw('mpl')

# %% [markdown]
# # Method 1

# %% [markdown]
# ## Circuit

# %%
def qc1(data, variational):

    n = num_features
    
    qreg1 = QuantumRegister(n,'q')
    qreg2 = QuantumRegister(n,'p')
    qc = QuantumCircuit(qreg1,qreg2)

    enc = ZZFeatureMap(feature_dimension = n)
    
    params0 = enc.parameters
    values0 = data

    enc.assign_parameters(dict(zip(params0, values0)),inplace = True)

    enc_gate = enc.to_gate()
    enc_gate.name = 'Enc'
    
    for i in range(num_reupload):

        var = TwoLocal(2*n, ['ry','rz'], 'cz', 'full', reps=1)

        params = var.parameters
        values = variational[i*var.num_parameters:(i+1)*var.num_parameters]
        
        var.assign_parameters(dict(zip(params, values)),inplace = True)

        var_gate = var.to_gate()    
        var_gate.name = f'Var{i+1}'
    
        qc.append(enc_gate,qreg1)
        #qc.append(enc_gate,qreg2)
        qc.append(var_gate,range(4))

    qc.save_statevector(label='sv')

    return qc

# %%
qc1(train_data[0],initial_point).draw('mpl')

# %% [markdown]
# ## Train Functions

# %%
def label_probability_1(state):

    reduced = partial_trace(state,[2,3])
    probabilities = reduced.probabilities_dict() 
    
    return probabilities

def classification_probability_1(all_data, variational):

    backend = AerSimulator()
    
    circs = [qc1(d, variational) for d in all_data]
    circs_transpiled = transpile(circs,backend=backend)

    jobs = backend.run(circs_transpiled)
    results = jobs.result()
    
    classification = [
        label_probability_1(results.data(i)['sv']) for i, c in enumerate(circs)]

    return classification

def cross_entropy_loss_1(classification, expected):
    """Calculate accuracy of predictions using cross entropy loss.
    Args:
        classification (dict): Dict where keys are possible classes,
                               and values are the probability our
                               circuit chooses that class.
        expected (int): Correct classification of the data point.

    Returns:
        float: Cross entropy loss
    """
    p = classification.get(expected)  # Prob. of correct classification
    return -np.log(p)


def cost_function_1(all_data, labels, variational):
    """Evaluates performance of our circuit with `variational`
    parameters on `data`.

    Args:
        data (list): List of data points to classify
        labels (list): List of correct labels for each data point
        variational (list): Parameters to use in circuit

    Returns:
        float: Cost (metric of performance)
    """
    classifications = classification_probability_1(all_data, variational)
    cost = 0
    for i, classification in enumerate(classifications):
        cost += cross_entropy_loss_1(classification, format(labels[i],'02b'))
    cost /= len(all_data)
    return cost

def objective_function_1(variational):
    """Cost function of circuit parameters on training data.
    The optimizer will attempt to minimize this."""
    return cost_function_1(train_data, train_labels, variational)

# %%
def performance_evaluation(data, labels, variational):
    """Gets classifier's most likely predictions and accuracy of those
    predictions.

    Args:
        data (list): List of data points to classify
        labels (list): List of correct labels for each data point
        variational (list): List of parameter values for classifier

    Returns:
        float: Average accuracy of classifier over `data`
        list: Classifier's label predictions for each data point
    """
    probability = classification_probability_1(data, variational)
    
    predictions = [int(max(p, key=p.get), 2) for p in probability]
    accuracy = 0

    for i, prediction in enumerate(predictions):
        if prediction == labels[i]:
            accuracy += 1
    accuracy /= len(labels)
    return accuracy, predictions

# %% [markdown]
# ## Enhanced OptimizerLog with Result saving

# %%
class OptimizerLog:
    """Enhanced optimizer log with automatic result saving"""
    def __init__(self, results_dir):
        self.results_dir = results_dir
        self.evaluations = []
        self.parameters  = []
        self.costs       = []
        self.train_accuracies = []
        self.test_accuracies  = []
        self.stepsizes        = []
        
    def update(self, evaluation, parameter, cost, stepsize, accepted):
        """Update and save intermediate results"""
        self.evaluations.append(evaluation)
        self.parameters.append(parameter.copy())
        self.costs.append(cost)
        self.stepsizes.append(stepsize)
        
        train_accuracy, _ = performance_evaluation(train_data, train_labels, parameter)
        test_accuracy, _  = performance_evaluation(test_data, test_labels, parameter)
        
        self.train_accuracies.append(train_accuracy)
        self.test_accuracies.append(test_accuracy)
        
        if len(self.evaluations) % 1 == 0:
            print(f" Iteration {len(self.evaluations):3d}: Loss = {cost:.4f}, Train Acc = {train_accuracy:0.4f}, Test Acc = {test_accuracy:0.4f}, Step = {stepsize:.4f}")
    
    def save_results(self, final_params, final_cost, optimizer_name):
        """Save final results to JSON and text files"""
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        
        # Final evaluation
        final_train_acc, train_predictions = performance_evaluation(train_data, train_labels, final_params)
        final_test_acc, test_predictions   = performance_evaluation(test_data, test_labels, final_params)
        
        # Prepare results dictionary
        results = {
            "experiment_info": {
                "timestamp": timestamp,
                "optimizer": optimizer_name,
                "dataset": DATASET_NUM,
                "total_iterations": len(self.evaluations)
            },
            "final_results": {
                "final_parameters": final_params.tolist(),
                "final_cost": float(final_cost),
                "final_train_accuracy": float(final_train_acc),
                "final_test_accuracy": float(final_test_acc),
                "train_predictions": train_predictions,
                "test_predictions": test_predictions
            },
            "training_history": {
                "evaluations": self.evaluations,
                "costs": self.costs,
                "train_accuracies": self.train_accuracies,
                "test_accuracies": self.test_accuracies,
                "stepsizes": self.stepsizes,
                "parameters": self.parameters
            },
            "data_shapes": {
                "train_data_shape": list(train_data.shape),
                "test_data_shape": list(test_data.shape),
                "train_labels_shape": list(train_labels.shape),
                "test_labels_shape": list(test_labels.shape)
            }
        }
        
        # Save JSON results
        json_filename = os.path.join(self.results_dir, f"results_{optimizer_name.lower()}_{timestamp}.json")
        with open(json_filename, 'w') as f:
            json.dump(results, f, indent=2)
        print(f"Results saved to: {json_filename}")
        
        # Save text summary
        txt_filename = os.path.join(self.results_dir, f"summary_{optimizer_name.lower()}_{timestamp}.txt")
        with open(txt_filename, 'w') as f:
            f.write(f"QML Training Results - {optimizer_name}\n")
            f.write(f"Dataset: {DATASET_NUM}\n")
            f.write(f"Timestamp: {timestamp}\n")
            f.write(f"Total Iterations: {len(self.evaluations)}\n")
            f.write(f"\nFinal Results:\n")
            f.write(f"  Final Cost: {final_cost:.6f}\n")
            f.write(f"  Final Train Accuracy: {final_train_acc:.4f}\n")
            f.write(f"  Final Test Accuracy: {final_test_acc:.4f}\n")
            f.write(f"\nBest Accuracies During Training:\n")
            f.write(f"  Best Train Accuracy: {max(self.train_accuracies):.4f}\n")
            f.write(f"  Best Test Accuracy: {max(self.test_accuracies):.4f}\n")
            f.write(f"  Lowest Cost: {min(self.costs):.6f}\n")
        print(f"Summary saved to: {txt_filename}")
        
        return results

# %%
# Method 1 Training with SPSA
print("Starting Method 1 (SPSA) Training...")
log_1 = OptimizerLog(results_dir=RESULTS_DIR)
optimizer_1 = SPSA(maxiter=600, callback=log_1.update)
result_1    = optimizer_1.minimize(objective_function_1, initial_point)

opt_var_1 = result_1.x
opt_value_1 = result_1.fun

print(f"\nOptimization completed!")
print(f"Final cost: {opt_value_1:.6f}")
print(f"Final parameters (first 5): {opt_var_1[:5]}")
# Out:
# Starting Method 1 (SPSA) Training...
#  Iteration   1: Loss = 1.4329, Train Acc = 0.3281, Test Acc = 0.2500, Step = 0.0887
#  Iteration   2: Loss = 1.4314, Train Acc = 0.2812, Test Acc = 0.2344, Step = 0.7885
#  Iteration   3: Loss = 1.4316, Train Acc = 0.3438, Test Acc = 0.2812, Step = 0.7144
#  Iteration   4: Loss = 1.4299, Train Acc = 0.3047, Test Acc = 0.2969, Step = 0.2935
#  Iteration   5: Loss = 1.4129, Train Acc = 0.2734, Test Acc = 0.2344, Step = 1.0038
#  Iteration   6: Loss = 1.4127, Train Acc = 0.2734, Test Acc = 0.2344, Step = 0.0208
#  Iteration   7: Loss = 1.4078, Train Acc = 0.2812, Test Acc = 0.2344, Step = 0.6269
#  Iteration   8: Loss = 1.4076, Train Acc = 0.2812, Test Acc = 0.2344, Step = 0.0846
#  Iteration   9: Loss = 1.4028, Train Acc = 0.3047, Test Acc = 0.2812, Step = 1.1370
#  Iteration  10: Loss = 1.3958, Train Acc = 0.2734, Test Acc = 0.2500, Step = 0.9723
#  Iteration  11: Loss = 1.3880, Train Acc = 0.3203, Test Acc = 0.3750, Step = 1.0818
#  Iteration  12: Loss = 1.3571, Train Acc = 0.3594, Test Acc = 0.3594, Step = 1.0733
#  Iteration  13: Loss = 1.3443, Train Acc = 0.3672, Test Acc = 0.3750, Step = 1.2042
#  Iteration  14: Loss = 1.3127, Train Acc = 0.3750, Test Acc = 0.3594, Step = 1.0539
#  Iteration  15: Loss = 1.3009, Train Acc = 0.3359, Test Acc = 0.2969, Step = 0.7199
#  Iteration  16: Loss = 1.2985, Train Acc = 0.3281, Test Acc = 0.3125, Step = 0.3370
#  Iteration  17: Loss = 1.2982, Train Acc = 0.3438, Test Acc = 0.3125, Step = 0.1009
#  Iteration  18: Loss = 1.2868, Train Acc = 0.3516, Test Acc = 0.3438, Step = 0.5787
#  Iteration  19: Loss = 1.2861, Train Acc = 0.3750, Test Acc = 0.3594, Step = 0.5372
#  Iteration  20: Loss = 1.2854, Train Acc = 0.4141, Test Acc = 0.2812, Step = 0.9662
#  Iteration  21: Loss = 1.2814, Train Acc = 0.4141, Test Acc = 0.3125, Step = 0.3001
#  Iteration  22: Loss = 1.2760, Train Acc = 0.3984, Test Acc = 0.2969, Step = 0.4520
#  Iteration  23: Loss = 1.2744, Train Acc = 0.4062, Test Acc = 0.3281, Step = 0.2412
#  Iteration  24: Loss = 1.2598, Train Acc = 0.4219, Test Acc = 0.3438, Step = 0.6762
#  Iteration  25: Loss = 1.2739, Train Acc = 0.4141, Test Acc = 0.3906, Step = 0.7451
#  Iteration  26: Loss = 1.2806, Train Acc = 0.3984, Test Acc = 0.3438, Step = 0.8714
#  Iteration  27: Loss = 1.2567, Train Acc = 0.3672, Test Acc = 0.4062, Step = 1.0445
#  Iteration  28: Loss = 1.2559, Train Acc = 0.3750, Test Acc = 0.4219, Step = 0.1098
#  Iteration  29: Loss = 1.2560, Train Acc = 0.3672, Test Acc = 0.4219, Step = 0.0422
#  Iteration  30: Loss = 1.2563, Train Acc = 0.4062, Test Acc = 0.3750, Step = 0.4203
#  Iteration  31: Loss = 1.2522, Train Acc = 0.4297, Test Acc = 0.3906, Step = 0.2726
#  Iteration  32: Loss = 1.2489, Train Acc = 0.4531, Test Acc = 0.4062, Step = 0.3415
#  Iteration  33: Loss = 1.2489, Train Acc = 0.4453, Test Acc = 0.3906, Step = 0.0517
#  Iteration  34: Loss = 1.2429, Train Acc = 0.4219, Test Acc = 0.3750, Step = 0.3147
#  Iteration  35: Loss = 1.2365, Train Acc = 0.4531, Test Acc = 0.3906, Step = 0.3433
#  Iteration  36: Loss = 1.2350, Train Acc = 0.4609, Test Acc = 0.3906, Step = 0.1580
#  Iteration  37: Loss = 1.2325, Train Acc = 0.4609, Test Acc = 0.3594, Step = 0.2288
#  Iteration  38: Loss = 1.2300, Train Acc = 0.4688, Test Acc = 0.3438, Step = 0.8002
#  Iteration  39: Loss = 1.2301, Train Acc = 0.4688, Test Acc = 0.3438, Step = 0.0145
#  Iteration  40: Loss = 1.2136, Train Acc = 0.4297, Test Acc = 0.4375, Step = 0.5358
#  Iteration  41: Loss = 1.2128, Train Acc = 0.4297, Test Acc = 0.4062, Step = 0.1742
#  Iteration  42: Loss = 1.1985, Train Acc = 0.4844, Test Acc = 0.3750, Step = 0.6778
#  Iteration  43: Loss = 1.1967, Train Acc = 0.4922, Test Acc = 0.4062, Step = 0.1670
#  Iteration  44: Loss = 1.1958, Train Acc = 0.5000, Test Acc = 0.3750, Step = 0.1217
#  Iteration  45: Loss = 1.1950, Train Acc = 0.5156, Test Acc = 0.3750, Step = 0.0968
#  Iteration  46: Loss = 1.1943, Train Acc = 0.5078, Test Acc = 0.3594, Step = 0.1661
#  Iteration  47: Loss = 1.1939, Train Acc = 0.5156, Test Acc = 0.3750, Step = 0.0879
#  Iteration  48: Loss = 1.1934, Train Acc = 0.5078, Test Acc = 0.3594, Step = 0.0614
#  Iteration  49: Loss = 1.1929, Train Acc = 0.4922, Test Acc = 0.3750, Step = 0.0716
#  Iteration  50: Loss = 1.1925, Train Acc = 0.4922, Test Acc = 0.3750, Step = 0.1077
#  Iteration  51: Loss = 1.1915, Train Acc = 0.5078, Test Acc = 0.3750, Step = 0.1261
#  Iteration  52: Loss = 1.1850, Train Acc = 0.5312, Test Acc = 0.4062, Step = 0.3064
#  Iteration  53: Loss = 1.1850, Train Acc = 0.5312, Test Acc = 0.4062, Step = 0.0060
#  Iteration  54: Loss = 1.1850, Train Acc = 0.5312, Test Acc = 0.4219, Step = 0.0148
#  Iteration  55: Loss = 1.1848, Train Acc = 0.5156, Test Acc = 0.4062, Step = 0.0394
#  Iteration  56: Loss = 1.1834, Train Acc = 0.5312, Test Acc = 0.4062, Step = 0.1634
#  Iteration  57: Loss = 1.1819, Train Acc = 0.5469, Test Acc = 0.4219, Step = 0.1585
#  Iteration  58: Loss = 1.1766, Train Acc = 0.5312, Test Acc = 0.4062, Step = 0.2453
#  Iteration  59: Loss = 1.1766, Train Acc = 0.5312, Test Acc = 0.4062, Step = 0.0169
#  Iteration  60: Loss = 1.1759, Train Acc = 0.5234, Test Acc = 0.4062, Step = 0.1204
#  Iteration  61: Loss = 1.1751, Train Acc = 0.5234, Test Acc = 0.3750, Step = 0.0870
#  Iteration  62: Loss = 1.1750, Train Acc = 0.5078, Test Acc = 0.3750, Step = 0.1034
#  Iteration  63: Loss = 1.1753, Train Acc = 0.5078, Test Acc = 0.3750, Step = 0.0348
#  Iteration  64: Loss = 1.1752, Train Acc = 0.5234, Test Acc = 0.3906, Step = 0.0931
#  Iteration  65: Loss = 1.1752, Train Acc = 0.5234, Test Acc = 0.3906, Step = 0.0028
#  Iteration  66: Loss = 1.1752, Train Acc = 0.5312, Test Acc = 0.3906, Step = 0.0441
#  Iteration  67: Loss = 1.1751, Train Acc = 0.5234, Test Acc = 0.3906, Step = 0.0527
#  Iteration  68: Loss = 1.1744, Train Acc = 0.5391, Test Acc = 0.4062, Step = 0.1618
#  Iteration  69: Loss = 1.1743, Train Acc = 0.5156, Test Acc = 0.3906, Step = 0.0404
#  Iteration  70: Loss = 1.1744, Train Acc = 0.5234, Test Acc = 0.3906, Step = 0.0396
#  Iteration  71: Loss = 1.1737, Train Acc = 0.5234, Test Acc = 0.3906, Step = 0.0599
#  Iteration  72: Loss = 1.1732, Train Acc = 0.5312, Test Acc = 0.3906, Step = 0.0955
#  Iteration  73: Loss = 1.1713, Train Acc = 0.5234, Test Acc = 0.4062, Step = 0.1809
#  Iteration  74: Loss = 1.1703, Train Acc = 0.5156, Test Acc = 0.4219, Step = 0.1442
#  Iteration  75: Loss = 1.1677, Train Acc = 0.5312, Test Acc = 0.3906, Step = 0.1880
#  Iteration  76: Loss = 1.1643, Train Acc = 0.5625, Test Acc = 0.4219, Step = 0.2170
#  Iteration  77: Loss = 1.1638, Train Acc = 0.5625, Test Acc = 0.3906, Step = 0.0775
#  Iteration  78: Loss = 1.1633, Train Acc = 0.5703, Test Acc = 0.4062, Step = 0.1304
#  Iteration  79: Loss = 1.1562, Train Acc = 0.5391, Test Acc = 0.4375, Step = 0.3834
#  Iteration  80: Loss = 1.1550, Train Acc = 0.5234, Test Acc = 0.4375, Step = 0.1043
#  Iteration  81: Loss = 1.1548, Train Acc = 0.5234, Test Acc = 0.4375, Step = 0.0607
#  Iteration  82: Loss = 1.1524, Train Acc = 0.5547, Test Acc = 0.4375, Step = 0.1682
#  Iteration  83: Loss = 1.1498, Train Acc = 0.5234, Test Acc = 0.4375, Step = 0.1909
#  Iteration  84: Loss = 1.1497, Train Acc = 0.5312, Test Acc = 0.4375, Step = 0.1109
#  Iteration  85: Loss = 1.1476, Train Acc = 0.5234, Test Acc = 0.4375, Step = 0.1487
#  Iteration  86: Loss = 1.1476, Train Acc = 0.5156, Test Acc = 0.4375, Step = 0.0272
#  Iteration  87: Loss = 1.1430, Train Acc = 0.5391, Test Acc = 0.4375, Step = 0.2474
#  Iteration  88: Loss = 1.1430, Train Acc = 0.5469, Test Acc = 0.4375, Step = 0.0499
#  Iteration  89: Loss = 1.1396, Train Acc = 0.5391, Test Acc = 0.4375, Step = 0.1731
#  Iteration  90: Loss = 1.1391, Train Acc = 0.5391, Test Acc = 0.4531, Step = 0.0731
#  Iteration  91: Loss = 1.1390, Train Acc = 0.5234, Test Acc = 0.4375, Step = 0.0503
#  Iteration  92: Loss = 1.1375, Train Acc = 0.5469, Test Acc = 0.4531, Step = 0.1390
#  Iteration  93: Loss = 1.1369, Train Acc = 0.5391, Test Acc = 0.4531, Step = 0.0931
#  Iteration  94: Loss = 1.1288, Train Acc = 0.5859, Test Acc = 0.4531, Step = 0.2945
#  Iteration  95: Loss = 1.1238, Train Acc = 0.5391, Test Acc = 0.4531, Step = 0.2722
#  Iteration  96: Loss = 1.1067, Train Acc = 0.5703, Test Acc = 0.4531, Step = 0.3705
#  Iteration  97: Loss = 1.1052, Train Acc = 0.5781, Test Acc = 0.4531, Step = 0.1081
#  Iteration  98: Loss = 1.1052, Train Acc = 0.5938, Test Acc = 0.4531, Step = 0.0070
#  Iteration  99: Loss = 1.1030, Train Acc = 0.5703, Test Acc = 0.4531, Step = 0.1881
#  Iteration 100: Loss = 1.1026, Train Acc = 0.5625, Test Acc = 0.4531, Step = 0.0603
Train Acc = 0.7812, Test Acc = 0.6875, Step = 0.0068
#  Iteration 599: Loss = 0.7111, Train Acc = 0.7812, Test Acc = 0.6875, Step = 0.0224
#  Iteration 600: Loss = 0.7110, Train Acc = 0.7891, Test Acc = 0.6875, Step = 0.0205
#
# Optimization completed!
# Final cost: 0.711029
# Final parameters (first 5): [-0.08783981 -0.09126686  0.51485032 -1.79043001 -1.40240522]

# %%
results_1 = log_1.save_results(opt_var_1, opt_value_1, "SPSA_Method1")

# %% [markdown]
# ## Generate and save plots

# %%
# Plot training progress
plt.figure(figsize=(15, 5))

# Cost plot
plt.subplot(1, 3, 1)
plt.plot(log_1.costs, 'b-o', markersize=3, label='SPSA Method 1')
plt.xlabel('Iteration')
plt.ylabel('Cost (Loss)')
plt.title(f'Training Loss - Dataset {DATASET_NUM}')
plt.grid(True, alpha=0.3)
plt.legend()
plt.yscale('log')

# Accuracy plots
plt.subplot(1, 3, 2)
plt.plot(log_1.train_accuracies, 'g-o', markersize=3, label='Train Accuracy')
plt.plot(log_1.test_accuracies, 'r-o', markersize=3, label='Test Accuracy')
plt.xlabel('Iteration')
plt.ylabel('Accuracy')
plt.title(f'Accuracy Progress - Dataset {DATASET_NUM}')
plt.grid(True, alpha=0.3)
plt.legend()
plt.ylim(0, 1)

# Step size plot
plt.subplot(1, 3, 3)
plt.plot(log_1.stepsizes, 'm-o', markersize=3, label='Step Size')
plt.xlabel('Iteration')
plt.ylabel('Step Size')
plt.title(f'Step Size Evolution - Dataset {DATASET_NUM}')
plt.grid(True, alpha=0.3)
plt.legend()

plt.tight_layout()

# Save plot
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
plot_filename = os.path.join(RESULTS_DIR, f"training_progress_spsa_{timestamp}.png")
plt.savefig(plot_filename, dpi=300, bbox_inches='tight')
print(f"Training progress plot saved to: {plot_filename}")
plt.show()

# %%
# Parameter evolution plot
if len(log_1.parameters) > 0:
    plt.figure(figsize=(12, 8))
    params_array = np.array(log_1.parameters)
    
    # Plot first 8 parameters
    for i in range(min(8, params_array.shape[1])):
        plt.subplot(2, 4, i+1)
        plt.plot(params_array[:, i], 'o-', markersize=2)
        plt.title(f'Parameter {i+1}')
        plt.grid(True, alpha=0.3)
        plt.xlabel('Iteration')
        plt.ylabel('Value')
    
    plt.tight_layout()
    param_plot_filename = os.path.join(RESULTS_DIR, f"parameter_evolution_spsa_{timestamp}.png")
    plt.savefig(param_plot_filename, dpi=300, bbox_inches='tight')
    print(f"Parameter evolution plot saved to: {param_plot_filename}")
    plt.show()
# Out:
# Parameter evolution plot saved to: results/checkerboard_dataset1\parameter_evolution_spsa_20250809_064222.png

# %% [markdown]
# ## Final Performance Analysis

# %%
# Final performance evaluation
final_train_acc, train_pred = performance_evaluation(train_data, train_labels, opt_var_1)
final_test_acc, test_pred   = performance_evaluation(test_data, test_labels, opt_var_1)

print(f"\n=== Final Performance Analysis - Dataset {DATASET_NUM} (SPSA) ===")
print(f"Final Training Accuracy: {final_train_acc:.4f}")
print(f"Final Test Accuracy: {final_test_acc:.4f}")
print(f"Final Cost: {opt_value_1:.6f}")
print(f"\nTraining completed successfully!")
print(f"All results saved in: {RESULTS_DIR}")
# Out:
# === Final Performance Analysis - Dataset 1 (SPSA) ===
# Final Training Accuracy: 0.5781
# Final Test Accuracy: 0.3750
# Final Cost: 1.180385
#
# Training completed successfully!
# All results saved in: results/checkerboard_dataset1

# %% [markdown]
# # Method 2

# %% [markdown]
# ## Circuit

# %%
def qc2(all_data, variational):
    
    n1 = num_register
    n2 = 2*num_features
    n = n1 + n2
    
    qreg_1 = QuantumRegister(n1,'r')
    qreg_2 = QuantumRegister(n2,'q')
    qreg_3 = QuantumRegister(1,'l')
    
    qc = QuantumCircuit(qreg_1,qreg_2,qreg_3)

    qc.h(qreg_1)
    qc.barrier()
    
    enc = QuantumCircuit(n1+2)
    
    for i in range(len(all_data)):        
        fm = ZZFeatureMap(feature_dimension=2)
        params0 = fm.parameters
        values0 = all_data[i]
        fm.assign_parameters(dict(zip(params0, values0)),inplace = True)
        fm_gate = fm.to_gate(label="ZZMap") 
        enc.append(fm_gate.control(num_ctrl_qubits=n1, ctrl_state=format(i, f'0{n1}b')),range(n1+2))

    enc_gate = enc.to_gate()
    enc_gate.name = 'Enc'

    for i in range(num_reupload):
        
        var = TwoLocal(n2, ['ry','rz'], 'cz', 'full', reps=1)
    
        params = var.parameters
        values = variational[i*var.num_parameters:(i+1)*var.num_parameters]
        
        var.assign_parameters(dict(zip(params, values)),inplace = True)
    
        var_gate = var.to_gate()    
        var_gate.name = f'Var{i+1}'
    
        qc.append(enc_gate,range(n1+2))
        qc.append(var_gate,range(n1,n1+n2))
         
    qc.save_statevector(label='sv0')
    
    qc.append(XGate().control(num_ctrl_qubits=4, ctrl_state='0000'),[n1-2,n1-1,n1,n1+1,n1+n2])
    qc.append(XGate().control(num_ctrl_qubits=4, ctrl_state='0101'),[n1-2,n1-1,n1,n1+1,n1+n2])
    qc.append(XGate().control(num_ctrl_qubits=4, ctrl_state='1010'),[n1-2,n1-1,n1,n1+1,n1+n2])
    qc.append(XGate().control(num_ctrl_qubits=4, ctrl_state='1111'),[n1-2,n1-1,n1,n1+1,n1+n2])
    
   
    qc.save_statevector(label='sv')
    
    return qc

# %%
qc2(train_data,initial_point).draw('mpl')

# %% [markdown]
# ## Train Functions

# %%
def label_probability_2(state):

    n = num_register + 2*num_features
    
    reduced = partial_trace(state,list(range(0,n)))
    probabilities = reduced.probabilities_dict()
    
    return probabilities

def classification_probability_2(all_data, variational):

    backend = AerSimulator(device='GPU')
    
    circ = qc2(all_data, variational)
    circ_transpiled = transpile(circ,backend=backend)

    jobs = backend.run(circ_transpiled)
    results = jobs.result()
    
    classification = label_probability_2(results.data()['sv'])
        
    return classification

def cross_entropy_loss_2(classification):
    """Calculate accuracy of predictions using cross entropy loss.
    Args:
        classification (dict): Dict where keys are possible classes,
                               and values are the probability our
                               circuit chooses that class.
        expected (int): Correct classification of the data point.

    Returns:
        float: Cross entropy loss
    """
    p = classification.get('1')  # Prob. of correct classification
    return -np.log(p)


def cost_function_2(all_data, variational):
    """Evaluates performance of our circuit with `variational`
    parameters on `data`.

    Args:
        data (list): List of data points to classify
        labels (list): List of correct labels for each data point
        variational (list): Parameters to use in circuit

    Returns:
        float: Cost (metric of performance)
    """
    classification = classification_probability_2(all_data, variational)
    cost = cross_entropy_loss_2(classification)
    
    return cost


def objective_function_2(variational):
    """Cost function of circuit parameters on training data.
    The optimizer will attempt to minimize this."""
    return cost_function_2(train_data, variational)

# %% [markdown]
# ## Train

# %%
# Method 2 Training with SPSA
print("Starting Method 2 (SPSA) Training...")
log_2       = OptimizerLog( results_dir = RESULTS_DIR)
optimizer_2 = SPSA(maxiter=600, callback=log_2.update)
result_2    = optimizer_2.minimize(objective_function_2, initial_point)

opt_var_2   = result_2.x
opt_value_2 = result_2.fun

print(f"\nMethod 2 Optimization completed!")
print(f"Final cost: {opt_value_2:.6f}")
print(f"Final parameters (first 5): {opt_var_2[:5]}")
# Out:
# Starting Method 2 (SPSA) Training...
#  Iteration   1: Loss = 1.4050, Train Acc = 0.2656, Test Acc = 0.1875, Step = 3.4323
#  Iteration   2: Loss = 1.3664, Train Acc = 0.1953, Test Acc = 0.2500, Step = 1.9313
#  Iteration   3: Loss = 1.3161, Train Acc = 0.3359, Test Acc = 0.2812, Step = 3.4212
#  Iteration   4: Loss = 1.3126, Train Acc = 0.3281, Test Acc = 0.2188, Step = 1.8263
#  Iteration   5: Loss = 1.2371, Train Acc = 0.3984, Test Acc = 0.2969, Step = 2.9948
#  Iteration   6: Loss = 1.2437, Train Acc = 0.3359, Test Acc = 0.2344, Step = 1.1742
#  Iteration   7: Loss = 1.3721, Train Acc = 0.2734, Test Acc = 0.3594, Step = 4.9062
#  Iteration   8: Loss = 1.3713, Train Acc = 0.2734, Test Acc = 0.3750, Step = 0.1886
#  Iteration   9: Loss = 1.3700, Train Acc = 0.2656, Test Acc = 0.4062, Step = 0.1138
#  Iteration  10: Loss = 1.3485, Train Acc = 0.3047, Test Acc = 0.2969, Step = 0.8663
#  Iteration  11: Loss = 1.3223, Train Acc = 0.2969, Test Acc = 0.2969, Step = 0.8705
#  Iteration  12: Loss = 1.3069, Train Acc = 0.3203, Test Acc = 0.3125, Step = 0.9369
#  Iteration  13: Loss = 1.2571, Train Acc = 0.3672, Test Acc = 0.3281, Step = 0.9560
#  Iteration  14: Loss = 1.2569, Train Acc = 0.3594, Test Acc = 0.3281, Step = 0.1313
#  Iteration  15: Loss = 1.2090, Train Acc = 0.3828, Test Acc = 0.3281, Step = 2.2742
#  Iteration  16: Loss = 1.2082, Train Acc = 0.4062, Test Acc = 0.3438, Step = 0.3816
#  Iteration  17: Loss = 1.2069, Train Acc = 0.3906, Test Acc = 0.3438, Step = 0.2576
#  Iteration  18: Loss = 1.2052, Train Acc = 0.3672, Test Acc = 0.3125, Step = 0.2000
#  Iteration  19: Loss = 1.2132, Train Acc = 0.4219, Test Acc = 0.2656, Step = 1.0848
#  Iteration  20: Loss = 1.2123, Train Acc = 0.4297, Test Acc = 0.2812, Step = 0.1636
#  Iteration  21: Loss = 1.2017, Train Acc = 0.3984, Test Acc = 0.4062, Step = 0.6711
#  Iteration  22: Loss = 1.2002, Train Acc = 0.4141, Test Acc = 0.3438, Step = 0.2807
#  Iteration  23: Loss = 1.1968, Train Acc = 0.3984, Test Acc = 0.3750, Step = 0.3828
#  Iteration  24: Loss = 1.1891, Train Acc = 0.4688, Test Acc = 0.3125, Step = 0.5845
#  Iteration  25: Loss = 1.1724, Train Acc = 0.4766, Test Acc = 0.3438, Step = 0.5594
#  Iteration  26: Loss = 1.1717, Train Acc = 0.4766, Test Acc = 0.3125, Step = 0.2206
#  Iteration  27: Loss = 1.1517, Train Acc = 0.4844, Test Acc = 0.3594, Step = 0.8231
#  Iteration  28: Loss = 1.1422, Train Acc = 0.4609, Test Acc = 0.3594, Step = 1.0236
#  Iteration  29: Loss = 1.1410, Train Acc = 0.4453, Test Acc = 0.3594, Step = 0.2724
#  Iteration  30: Loss = 1.1442, Train Acc = 0.4375, Test Acc = 0.4219, Step = 0.7137
#  Iteration  31: Loss = 1.1434, Train Acc = 0.5000, Test Acc = 0.4375, Step = 1.0154
#  Iteration  32: Loss = 1.1333, Train Acc = 0.4766, Test Acc = 0.4219, Step = 0.4785
#  Iteration  33: Loss = 1.1131, Train Acc = 0.4922, Test Acc = 0.3906, Step = 0.6605
#  Iteration  34: Loss = 1.1130, Train Acc = 0.4844, Test Acc = 0.3906, Step = 0.0541
#  Iteration  35: Loss = 1.1129, Train Acc = 0.4922, Test Acc = 0.4062, Step = 0.1342
#  Iteration  36: Loss = 1.1052, Train Acc = 0.4766, Test Acc = 0.4062, Step = 0.4782
#  Iteration  37: Loss = 1.1045, Train Acc = 0.4609, Test Acc = 0.4375, Step = 0.3192
#  Iteration  38: Loss = 1.0676, Train Acc = 0.4453, Test Acc = 0.4375, Step = 1.1375
#  Iteration  39: Loss = 1.0427, Train Acc = 0.4688, Test Acc = 0.4219, Step = 0.8197
#  Iteration  40: Loss = 1.0171, Train Acc = 0.4766, Test Acc = 0.5000, Step = 0.8597
#  Iteration  41: Loss = 1.0052, Train Acc = 0.5391, Test Acc = 0.5000, Step = 0.6831
#  Iteration  42: Loss = 0.9985, Train Acc = 0.5625, Test Acc = 0.4844, Step = 0.3549
#  Iteration  43: Loss = 0.9863, Train Acc = 0.5078, Test Acc = 0.4375, Step = 0.6521
#  Iteration  44: Loss = 0.9816, Train Acc = 0.5234, Test Acc = 0.4375, Step = 0.3906
#  Iteration  45: Loss = 0.9786, Train Acc = 0.5078, Test Acc = 0.4531, Step = 0.4758
#  Iteration  46: Loss = 0.9785, Train Acc = 0.5234, Test Acc = 0.4375, Step = 0.1183
#  Iteration  47: Loss = 0.9764, Train Acc = 0.5469, Test Acc = 0.4375, Step = 0.4467
#  Iteration  48: Loss = 0.9730, Train Acc = 0.5391, Test Acc = 0.4844, Step = 0.4273
#  Iteration  49: Loss = 0.9717, Train Acc = 0.5391, Test Acc = 0.4844, Step = 0.2235
#  Iteration  50: Loss = 0.9718, Train Acc = 0.5391, Test Acc = 0.4844, Step = 0.0354
#  Iteration  51: Loss = 0.9723, Train Acc = 0.5234, Test Acc = 0.4844, Step = 0.0678
#  Iteration  52: Loss = 0.9673, Train Acc = 0.5234, Test Acc = 0.4844, Step = 0.5047
#  Iteration  53: Loss = 0.9676, Train Acc = 0.5312, Test Acc = 0.4844, Step = 0.0606
#  Iteration  54: Loss = 0.9646, Train Acc = 0.5469, Test Acc = 0.4375, Step = 0.3256
#  Iteration  55: Loss = 0.9646, Train Acc = 0.5469, Test Acc = 0.4531, Step = 0.0210
#  Iteration  56: Loss = 0.9644, Train Acc = 0.5547, Test Acc = 0.4531, Step = 0.0439
#  Iteration  57: Loss = 0.9586, Train Acc = 0.5078, Test Acc = 0.4688, Step = 0.4195
#  Iteration  58: Loss = 0.9542, Train Acc = 0.5312, Test Acc = 0.4375, Step = 0.3691
#  Iteration  59: Loss = 0.9542, Train Acc = 0.5391, Test Acc = 0.4375, Step = 0.0286
#  Iteration  60: Loss = 0.9541, Train Acc = 0.5469, Test Acc = 0.4375, Step = 0.0390
#  Iteration  61: Loss = 0.9511, Train Acc = 0.5625, Test Acc = 0.4688, Step = 0.2114
#  Iteration  62: Loss = 0.9504, Train Acc = 0.5625, Test Acc = 0.4688, Step = 0.1465
#  Iteration  63: Loss = 0.9496, Train Acc = 0.5781, Test Acc = 0.4688, Step = 0.1205
#  Iteration  64: Loss = 0.9405, Train Acc = 0.6250, Test Acc = 0.4688, Step = 0.4700
#  Iteration  65: Loss = 0.9392, Train Acc = 0.6250, Test Acc = 0.5156, Step = 0.1555
#  Iteration  66: Loss = 0.9385, Train Acc = 0.6328, Test Acc = 0.5156, Step = 0.1978
#  Iteration  67: Loss = 0.9386, Train Acc = 0.6250, Test Acc = 0.5156, Step = 0.0465
#  Iteration  68: Loss = 0.9383, Train Acc = 0.6328, Test Acc = 0.5156, Step = 0.0924
#  Iteration  69: Loss = 0.9383, Train Acc = 0.6406, Test Acc = 0.5312, Step = 0.1715
#  Iteration  70: Loss = 0.9362, Train Acc = 0.6328, Test Acc = 0.5312, Step = 0.1797
#  Iteration  71: Loss = 0.9350, Train Acc = 0.6094, Test Acc = 0.5312, Step = 0.1821
#  Iteration  72: Loss = 0.9337, Train Acc = 0.6094, Test Acc = 0.5312, Step = 0.1425
#  Iteration  73: Loss = 0.9335, Train Acc = 0.5938, Test Acc = 0.5312, Step = 0.0432
#  Iteration  74: Loss = 0.9329, Train Acc = 0.5938, Test Acc = 0.5312, Step = 0.0941
#  Iteration  75: Loss = 0.9325, Train Acc = 0.5703, Test Acc = 0.5469, Step = 0.1668
#  Iteration  76: Loss = 0.9322, Train Acc = 0.5703, Test Acc = 0.5312, Step = 0.0645
#  Iteration  77: Loss = 0.9310, Train Acc = 0.5859, Test Acc = 0.5469, Step = 0.1407
#  Iteration  78: Loss = 0.9306, Train Acc = 0.5703, Test Acc = 0.5469, Step = 0.0889
#  Iteration  79: Loss = 0.9301, Train Acc = 0.5938, Test Acc = 0.5469, Step = 0.0797
#  Iteration  80: Loss = 0.9299, Train Acc = 0.5938, Test Acc = 0.5469, Step = 0.0559
#  Iteration  81: Loss = 0.9288, Train Acc = 0.5938, Test Acc = 0.5469, Step = 0.1732
#  Iteration  82: Loss = 0.9286, Train Acc = 0.5781, Test Acc = 0.5469, Step = 0.0847
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 5
#       3 log_2       = OptimizerLog( results_dir = RESULTS_DIR)
#       4 optimizer_2 = SPSA(maxiter=200, callback=log_2.update)
# ----> 5 result_2    = optimizer_2.minimize(objective_function_2, initial_point)
#       7 opt_var_2   = result_2.x
#       8 opt_value_2 = result_2.fun
#
# File ~/miniforge3/envs/qiskit-1-4-2/lib/python3.12/site-packages/qiskit_machine_learning/optimizers/spsa.py:562, in SPSA.minimize(self, fun, x0, jac, bounds)
#     560 iteration_start = time()
#     561 # compute update
# --> 562 fx_estimate, update = self._compute_update(fun, x, k, next(eps), lse_solver)
#     564 # trust region
#     565 if self.trust_region:
#
# File ~/miniforge3/envs/qiskit-1-4-2/lib/python3.12/site-packages/qiskit_machine_learning/optimizers/spsa.py:493, in SPSA._compute_update(self, loss, x, k, eps, lse_solver)
#     490     num_samples = self.resamplings
#     492 # accumulate the number of samples
# --> 493 value, gradient, hessian = self._point_estimate(loss, x, eps, num_samples)
#     495 # precondition gradient with inverse Hessian, if specified
#     496 if self.second_order:
#
# File ~/miniforge3/envs/qiskit-1-4-2/lib/python3.12/site-packages/qiskit_machine_learning/optimizers/spsa.py:469, in SPSA._point_estimate(self, loss, x, eps, num_samples)
#     466 delta1 = deltas1[i]
#     467 delta2 = deltas2[i] if self.second_order else None
# --> 469 value_sample, gradient_sample, hessian_sample = self._point_sample(
#     470     loss, x, eps, delta1, delta2
#     471 )
#     472 value_estimate += value_sample
#     473 gradient_estimate += gradient_sample
#
# File ~/miniforge3/envs/qiskit-1-4-2/lib/python3.12/site-packages/qiskit_machine_learning/optimizers/spsa.py:430, in SPSA._point_sample(self, loss, x, eps, delta1, delta2)
#     427     self._nfev += 2
#     429 # batch evaluate the points (if possible)
# --> 430 values = _batch_evaluate(loss, points, self._max_evals_grouped)
#     432 plus = values[0]
#     433 minus = values[1]
#
# File ~/miniforge3/envs/qiskit-1-4-2/lib/python3.12/site-packages/qiskit_machine_learning/optimizers/spsa.py:698, in _batch_evaluate(function, points, max_evals_grouped, unpack_points)
#     694 # if the function cannot handle lists of points as input, cover this case immediately
#     695 if max_evals_grouped is None or max_evals_grouped == 1:
#     696     # support functions with multiple arguments where the points are given in a tuple
#     697     return [
# --> 698         function(*point) if isinstance(point, tuple) else function(point) for point in points
#     699     ]
#     701 num_points = len(points)
#     703 # get the number of batches
#
# Cell In[30], line 60, in objective_function_2(variational)
#      57 def objective_function_2(variational):
#      58     """Cost function of circuit parameters on training data.
#      59     The optimizer will attempt to minimize this."""
# ---> 60     return cost_function_2(train_data, variational)
#
# Cell In[30], line 51, in cost_function_2(all_data, variational)
#      39 def cost_function_2(all_data, variational):
#      40     """Evaluates performance of our circuit with `variational`
#      41     parameters on `data`.
#      42
#    (...)     49         float: Cost (metric of performance)
#      50     """
# ---> 51     classification = classification_probability_2(all_data, variational)
#      52     cost = cross_entropy_loss_2(classification)
#      54     return cost
#
# Cell In[30], line 14, in classification_probability_2(all_data, variational)
#      10 def classification_probability_2(all_data, variational):
#      12     backend = AerSimulator(device='GPU')
# ---> 14     circ = qc2(all_data, variational)
#      15     circ_transpiled = transpile(circ,backend=backend)
#      17     jobs = backend.run(circ_transpiled)
#
# Cell In[28], line 24, in qc2(all_data, variational)
#      22     fm.assign_parameters(dict(zip(params0, values0)),inplace = True)
#      23     fm_gate = fm.to_gate(label="ZZMap")
# ---> 24     enc.append(fm_gate.control(num_ctrl_qubits=n1, ctrl_state=format(i, f'0{n1}b')),range(n1+2))
#      26 enc_gate = enc.to_gate()
#      27 enc_gate.name = 'Enc'
#
# File ~/miniforge3/envs/qiskit-1-4-2/lib/python3.12/site-packages/qiskit/circuit/gate.py:142, in Gate.control(self, num_ctrl_qubits, label, ctrl_state, annotated)
#     138 if not annotated:  # captures both None and False
#     139     # pylint: disable=cyclic-import
#     140     from .add_control import add_control
# --> 142     return add_control(self, num_ctrl_qubits, label, ctrl_state)
#     144 else:
#     145     return AnnotatedOperation(
#     146         self, ControlModifier(num_ctrl_qubits=num_ctrl_qubits, ctrl_state=ctrl_state)
#     147     )
#
# File ~/miniforge3/envs/qiskit-1-4-2/lib/python3.12/site-packages/qiskit/circuit/add_control.py:62, in add_control(operation, num_ctrl_qubits, label, ctrl_state)
#      59 if isinstance(operation, UnitaryGate):
#      60     # attempt decomposition
#      61     operation._define()
# ---> 62 cgate = control(operation, num_ctrl_qubits=num_ctrl_qubits, label=label, ctrl_state=ctrl_state)
#      63 if operation.label is not None:
#      64     cgate.base_gate = cgate.base_gate.to_mutable()
#
# File ~/miniforge3/envs/qiskit-1-4-2/lib/python3.12/site-packages/qiskit/circuit/add_control.py:140, in control(operation, num_ctrl_qubits, label, ctrl_state)
#     137 else:
#     138     target = [q_target[bit_indices[qarg]] for qarg in qargs]
# --> 140 apply_basic_controlled_gate(controlled_circ, gate, q_control, target)
#     142 if gate.definition is not None and gate.definition.global_phase and gate.name != "rz":
#     143     global_phase += gate.definition.global_phase
#
# File ~/miniforge3/envs/qiskit-1-4-2/lib/python3.12/site-packages/qiskit/circuit/add_control.py:254, in apply_basic_controlled_gate(circuit, gate, controls, target)
#     252         else:
#     253             circuit.mcp(lamb, controls, target)
# --> 254             circuit.mcry(
#     255                 theta,
#     256                 controls,
#     257                 target,
#     258                 use_basis_gates=True,
#     259             )
#     260             circuit.mcp(phi, controls, target)
#     262 elif gate.name == "z":
#
# File ~/miniforge3/envs/qiskit-1-4-2/lib/python3.12/site-packages/qiskit/circuit/library/standard_gates/multi_control_rotation_gates.py:342, in mcry(self, theta, q_controls, q_target, q_ancillae, mode, use_basis_gates)
#     339         if isinstance(theta, ParameterExpression):
#     340             raise QiskitError(f"Cannot synthesize MCRY with unbound parameter: {theta}.")
# --> 342         cgate = _mcsu2_real_diagonal(
#     343             RYGate(theta).to_matrix(),
#     344             num_controls=len(control_qubits),
#     345             use_basis_gates=use_basis_gates,
#     346         )
#     347         self.compose(cgate, control_qubits + [target_qubit], inplace=True)
#     348 else:
#
# File ~/miniforge3/envs/qiskit-1-4-2/lib/python3.12/site-packages/qiskit/circuit/library/standard_gates/multi_control_rotation_gates.py:203, in _mcsu2_real_diagonal(unitary, num_controls, ctrl_state, use_basis_gates)
#     200     circuit.h(target)
#     202 if use_basis_gates:
# --> 203     circuit = transpile(circuit, basis_gates=["p", "u", "cx"], qubits_initially_zero=False)
#     205 return circuit
#
# File ~/miniforge3/envs/qiskit-1-4-2/lib/python3.12/site-packages/qiskit/utils/deprecation.py:184, in deprecate_arg.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     171 @functools.wraps(func)
#     172 def wrapper(*args, **kwargs):
#     173     _maybe_warn_and_rename_kwarg(
#     174         args,
#     175         kwargs,
#    (...)    182         predicate=predicate,
#     183     )
# --> 184     return func(*args, **kwargs)
#
# File ~/miniforge3/envs/qiskit-1-4-2/lib/python3.12/site-packages/qiskit/utils/deprecation.py:184, in deprecate_arg.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     171 @functools.wraps(func)
#     172 def wrapper(*args, **kwargs):
#     173     _maybe_warn_and_rename_kwarg(
#     174         args,
#     175         kwargs,
#    (...)    182         predicate=predicate,
#     183     )
# --> 184     return func(*args, **kwargs)
#
#     [... skipping similar frames: deprecate_arg.<locals>.decorator.<locals>.wrapper at line 184 (1 times)]
#
# File ~/miniforge3/envs/qiskit-1-4-2/lib/python3.12/site-packages/qiskit/utils/deprecation.py:184, in deprecate_arg.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     171 @functools.wraps(func)
#     172 def wrapper(*args, **kwargs):
#     173     _maybe_warn_and_rename_kwarg(
#     174         args,
#     175         kwargs,
#    (...)    182         predicate=predicate,
#     183     )
# --> 184     return func(*args, **kwargs)
#
# File ~/miniforge3/envs/qiskit-1-4-2/lib/python3.12/site-packages/qiskit/compiler/transpiler.py:423, in transpile(circuits, backend, basis_gates, inst_map, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, approximation_degree, timing_constraints, seed_transpiler, optimization_level, callback, output_name, unitary_synthesis_method, unitary_synthesis_plugin_config, target, hls_config, init_method, optimization_method, ignore_backend_supplied_default_methods, num_processes, qubits_initially_zero)
#     411     warnings.filterwarnings(
#     412         "ignore",
#     413         category=DeprecationWarning,
#     414         message=".*``instruction_durations`` is deprecated as of Qiskit 1.3.*",
#     415         module="qiskit",
#     416     )
#     417     warnings.filterwarnings(
#     418         "ignore",
#     419         category=DeprecationWarning,
#     420         message=".*``backend_properties`` is deprecated as of Qiskit 1.3.*",
#     421         module="qiskit",
#     422     )
# --> 423     pm = generate_preset_pass_manager(
#     424         optimization_level,
#     425         target=target,
#     426         backend=backend,
#     427         basis_gates=basis_gates,
#     428         coupling_map=coupling_map,
#     429         instruction_durations=instruction_durations,
#     430         backend_properties=backend_properties,
#     431         timing_constraints=timing_constraints,
#     432         inst_map=inst_map,
#     433         initial_layout=initial_layout,
#     434         layout_method=layout_method,
#     435         routing_method=routing_method,
#     436         translation_method=translation_method,
#     437         scheduling_method=scheduling_method,
#     438         approximation_degree=approximation_degree,
#     439         seed_transpiler=seed_transpiler,
#     440         unitary_synthesis_method=unitary_synthesis_method,
#     441         unitary_synthesis_plugin_config=unitary_synthesis_plugin_config,
#     442         hls_config=hls_config,
#     443         init_method=init_method,
#     444         optimization_method=optimization_method,
#     445         dt=dt,
#     446         qubits_initially_zero=qubits_initially_zero,
#     447     )
#     449 out_circuits = pm.run(circuits, callback=callback, num_processes=num_processes)
#     451 for name, circ in zip(output_name, out_circuits):
#
# File ~/miniforge3/envs/qiskit-1-4-2/lib/python3.12/site-packages/qiskit/utils/deprecation.py:184, in deprecate_arg.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     171 @functools.wraps(func)
#     172 def wrapper(*args, **kwargs):
#     173     _maybe_warn_and_rename_kwarg(
#     174         args,
#     175         kwargs,
#    (...)    182         predicate=predicate,
#     183     )
# --> 184     return func(*args, **kwargs)
#
# File ~/miniforge3/envs/qiskit-1-4-2/lib/python3.12/site-packages/qiskit/utils/deprecation.py:184, in deprecate_arg.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     171 @functools.wraps(func)
#     172 def wrapper(*args, **kwargs):
#     173     _maybe_warn_and_rename_kwarg(
#     174         args,
#     175         kwargs,
#    (...)    182         predicate=predicate,
#     183     )
# --> 184     return func(*args, **kwargs)
#
#     [... skipping similar frames: deprecate_arg.<locals>.decorator.<locals>.wrapper at line 184 (1 times)]
#
# File ~/miniforge3/envs/qiskit-1-4-2/lib/python3.12/site-packages/qiskit/utils/deprecation.py:184, in deprecate_arg.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     171 @functools.wraps(func)
#     172 def wrapper(*args, **kwargs):
#     173     _maybe_warn_and_rename_kwarg(
#     174         args,
#     175         kwargs,
#    (...)    182         predicate=predicate,
#     183     )
# --> 184     return func(*args, **kwargs)
#
# File ~/miniforge3/envs/qiskit-1-4-2/lib/python3.12/site-packages/qiskit/transpiler/preset_passmanagers/generate_preset_pass_manager.py:473, in generate_preset_pass_manager(optimization_level, backend, target, basis_gates, inst_map, coupling_map, instruction_durations, backend_properties, timing_constraints, initial_layout, layout_method, routing_method, translation_method, scheduling_method, approximation_degree, seed_transpiler, unitary_synthesis_method, unitary_synthesis_plugin_config, hls_config, init_method, optimization_method, dt, qubits_initially_zero, _skip_target)
#     471     pm = level_1_pass_manager(pm_config)
#     472 elif optimization_level == 2:
# --> 473     pm = level_2_pass_manager(pm_config)
#     474 elif optimization_level == 3:
#     475     pm = level_3_pass_manager(pm_config)
#
# File ~/miniforge3/envs/qiskit-1-4-2/lib/python3.12/site-packages/qiskit/transpiler/preset_passmanagers/level2.py:50, in level_2_pass_manager(pass_manager_config)
#      27 def level_2_pass_manager(pass_manager_config: PassManagerConfig) -> StagedPassManager:
#      28     """Level 2 pass manager: medium optimization by initial layout selection and
#      29     gate cancellation using commutativity rules.
#      30
#    (...)     48         TranspilerError: if the passmanager config is invalid.
#      49     """
# ---> 50     plugin_manager = PassManagerStagePluginManager()
#      51     basis_gates = pass_manager_config.basis_gates
#      52     coupling_map = pass_manager_config.coupling_map
#
# File ~/miniforge3/envs/qiskit-1-4-2/lib/python3.12/site-packages/qiskit/transpiler/preset_passmanagers/plugin.py:209, in PassManagerStagePluginManager.__init__(self)
#     205 super().__init__()
#     206 self.init_plugins = stevedore.ExtensionManager(
#     207     "qiskit.transpiler.init", invoke_on_load=True, propagate_map_exceptions=True
#     208 )
# --> 209 self.layout_plugins = stevedore.ExtensionManager(
#     210     "qiskit.transpiler.layout", invoke_on_load=True, propagate_map_exceptions=True
#     211 )
#     212 self.routing_plugins = stevedore.ExtensionManager(
#     213     "qiskit.transpiler.routing", invoke_on_load=True, propagate_map_exceptions=True
#     214 )
#     215 self.translation_plugins = stevedore.ExtensionManager(
#     216     "qiskit.transpiler.translation", invoke_on_load=True, propagate_map_exceptions=True
#     217 )
#
# File ~/miniforge3/envs/qiskit-1-4-2/lib/python3.12/site-packages/stevedore/extension.py:118, in ExtensionManager.__init__(self, namespace, invoke_on_load, invoke_args, invoke_kwds, propagate_map_exceptions, on_load_failure_callback, verify_requirements)
#     107 def __init__(self, namespace,
#     108              invoke_on_load=False,
#     109              invoke_args=(),
#    (...)    112              on_load_failure_callback=None,
#     113              verify_requirements=False):
#     114     self._init_attributes(
#     115         namespace,
#     116         propagate_map_exceptions=propagate_map_exceptions,
#     117         on_load_failure_callback=on_load_failure_callback)
# --> 118     extensions = self._load_plugins(invoke_on_load,
#     119                                     invoke_args,
#     120                                     invoke_kwds,
#     121                                     verify_requirements)
#     122     self._init_plugins(extensions)
#
# File ~/miniforge3/envs/qiskit-1-4-2/lib/python3.12/site-packages/stevedore/extension.py:206, in ExtensionManager._load_plugins(self, invoke_on_load, invoke_args, invoke_kwds, verify_requirements)
#     204 LOG.debug('found extension %r', ep)
#     205 try:
# --> 206     ext = self._load_one_plugin(ep,
#     207                                 invoke_on_load,
#     208                                 invoke_args,
#     209                                 invoke_kwds,
#     210                                 verify_requirements,
#     211                                 )
#     212     if ext:
#     213         extensions.append(ext)
#
# File ~/miniforge3/envs/qiskit-1-4-2/lib/python3.12/site-packages/stevedore/extension.py:240, in ExtensionManager._load_one_plugin(self, ep, invoke_on_load, invoke_args, invoke_kwds, verify_requirements)
#     238     plugin = ep.resolve()
#     239 else:
# --> 240     plugin = ep.load()
#     241 if invoke_on_load:
#     242     obj = plugin(*invoke_args, **invoke_kwds)
#
# File ~/miniforge3/envs/qiskit-1-4-2/lib/python3.12/importlib/metadata/__init__.py:206, in EntryPoint.load(self)
#     204 match = self.pattern.match(self.value)
#     205 module = import_module(match.group('module'))
# --> 206 attrs = filter(None, (match.group('attr') or '').split('.'))
#     207 return functools.reduce(getattr, attrs, module)
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/miniforge3/envs/qiskit-1-4-2/lib/python3.12/site-packages/IPython/core/async_helpers.py:128, in _pseudo_sync_runner(coro)
#     120 """
#     121 A runner that does not really allow async execution, and just advance the coroutine.
#     122
#    (...)    125 Credit to Nathaniel Smith
#     126 """
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#     130     return exc.value
#
# File ~/miniforge3/envs/qiskit-1-4-2/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3413, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3409 exec_count = self.execution_count
#    3410 if result.error_in_exec:
#    3411     # Store formatted traceback and error details
#    3412     self.history_manager.exceptions[exec_count] = (
# -> 3413         self._format_exception_for_storage(result.error_in_exec)
#    3414     )
#    3416 # Each cell is a *single* input, regardless of how many lines it has
#    3417 self.execution_count += 1
#
# File ~/miniforge3/envs/qiskit-1-4-2/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3467, in InteractiveShell._format_exception_for_storage(self, exception, filename, running_compiled_code)
#    3464         stb = evalue._render_traceback_()
#    3465     else:
#    3466         # Otherwise, use InteractiveTB to format the traceback.
# -> 3467         stb = self.InteractiveTB.structured_traceback(
#    3468             etype, evalue, tb, tb_offset=1
#    3469         )
#    3470 except Exception:
#    3471     # In case formatting fails, fallback to Python's built-in formatting.
#    3472     stb = traceback.format_exception(etype, evalue, tb)
#
# File ~/miniforge3/envs/qiskit-1-4-2/lib/python3.12/site-packages/IPython/core/ultratb.py:1182, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1180 else:
#    1181     self.tb = etb
# -> 1182 return FormattedTB.structured_traceback(
#    1183     self, etype, evalue, etb, tb_offset, context
#    1184 )
#
# File ~/miniforge3/envs/qiskit-1-4-2/lib/python3.12/site-packages/IPython/core/ultratb.py:1053, in FormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1050 mode = self.mode
#    1051 if mode in self.verbose_modes:
#    1052     # Verbose modes need a full traceback
# -> 1053     return VerboseTB.structured_traceback(
#    1054         self, etype, evalue, etb, tb_offset, context
#    1055     )
#    1056 elif mode == "Docs":
#    1057     # return DocTB
#    1058     return DocTB(
#    1059         theme_name=self._theme_name,
#    1060         call_pdb=self.call_pdb,
#    (...)   1068         etype, evalue, etb, tb_offset, 1
#    1069     )  # type: ignore[arg-type]
#
# File ~/miniforge3/envs/qiskit-1-4-2/lib/python3.12/site-packages/IPython/core/ultratb.py:861, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     852 def structured_traceback(
#     853     self,
#     854     etype: type,
#    (...)    858     context: int = 5,
#     859 ) -> list[str]:
#     860     """Return a nice text document describing the traceback."""
# --> 861     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#     862         etype, evalue, etb, context, tb_offset
#     863     )
#     865     termsize = min(75, get_terminal_size()[0])
#     866     theme = theme_table[self._theme_name]
#
# File ~/miniforge3/envs/qiskit-1-4-2/lib/python3.12/site-packages/IPython/core/ultratb.py:746, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, context, tb_offset)
#     744 assert isinstance(tb_offset, int)
#     745 head = self.prepare_header(str(etype), self.long_header)
# --> 746 records = self.get_records(etb, context, tb_offset) if etb else []
#     748 frames = []
#     749 skipped = 0
#
# File ~/miniforge3/envs/qiskit-1-4-2/lib/python3.12/site-packages/IPython/core/ultratb.py:819, in VerboseTB.get_records(self, etb, context, tb_offset)
#     817 while cf is not None:
#     818     try:
# --> 819         mod = inspect.getmodule(cf.tb_frame)
#     820         if mod is not None:
#     821             mod_name = mod.__name__
#
# File ~/miniforge3/envs/qiskit-1-4-2/lib/python3.12/inspect.py:1009, in getmodule(object, _filename)
#    1007 if ismodule(module) and hasattr(module, '__file__'):
#    1008     f = module.__file__
# -> 1009     if f == _filesbymodname.get(modname, None):
#    1010         # Have already mapped this module, so skip it
#    1011         continue
#    1012     _filesbymodname[modname] = f
#
# KeyboardInterrupt:

# %%
# Save Method 2 results
results_2 = log_2.save_results(opt_var_2, opt_value_2, "SPSA_Method2")

# %% [markdown]
# ## Method 2 - Generate and Save Plots

# %%
# Method 2 - Plot training progress
plt.figure(figsize=(15, 5))

# Cost plot
plt.subplot(1, 3, 1)
plt.plot(log_2.costs, 'b-o', markersize=3, label='SPSA Method 2')
plt.xlabel('Iteration')
plt.ylabel('Cost (Loss)')
plt.title(f'Method 2 Training Loss - Dataset {DATASET_NUM}')
plt.grid(True, alpha=0.3)
plt.legend()
plt.yscale('log')

# Accuracy plots
plt.subplot(1, 3, 2)
plt.plot(log_2.train_accuracies, 'g-o', markersize=3, label='Train Accuracy')
plt.plot(log_2.test_accuracies, 'r-o', markersize=3, label='Test Accuracy')
plt.xlabel('Iteration')
plt.ylabel('Accuracy')
plt.title(f'Method 2 Accuracy Progress - Dataset {DATASET_NUM}')
plt.grid(True, alpha=0.3)
plt.legend()
plt.ylim(0, 1)

# Step size plot
plt.subplot(1, 3, 3)
plt.plot(log_2.stepsizes, 'm-o', markersize=3, label='Step Size')
plt.xlabel('Iteration')
plt.ylabel('Step Size')
plt.title(f'Method 2 Step Size Evolution - Dataset {DATASET_NUM}')
plt.grid(True, alpha=0.3)
plt.legend()

plt.tight_layout()

# Save plot
timestamp_2 = datetime.now().strftime("%Y%m%d_%H%M%S")
plot_filename_2 = os.path.join(RESULTS_DIR, f"method2_training_progress_spsa_{timestamp_2}.png")
plt.savefig(plot_filename_2, dpi=300, bbox_inches='tight')
print(f"Method 2 training progress plot saved to: {plot_filename_2}")
plt.show()

# %%
# Method 2 - Parameter evolution plot
if len(log_2.parameters) > 0:
    plt.figure(figsize=(12, 8))
    params_array_2 = np.array(log_2.parameters)
    
    # Plot first 8 parameters
    for i in range(min(8, params_array_2.shape[1])):
        plt.subplot(2, 4, i+1)
        plt.plot(params_array_2[:, i], 'o-', markersize=2)
        plt.title(f'Method 2 - Parameter {i+1}')
        plt.grid(True, alpha=0.3)
        plt.xlabel('Iteration')
        plt.ylabel('Value')
    
    plt.tight_layout()
    param_plot_filename_2 = os.path.join(RESULTS_DIR, f"method2_parameter_evolution_spsa_{timestamp_2}.png")
    plt.savefig(param_plot_filename_2, dpi=300, bbox_inches='tight')
    print(f"Method 2 parameter evolution plot saved to: {param_plot_filename_2}")
    plt.show()

# %% [markdown]
# ## Method 2 - Final Performance Analysis

# %%
# Method 2 - Final performance evaluation
final_train_acc_2, train_pred_2 = performance_evaluation(train_data, train_labels, opt_var_2)
final_test_acc_2, test_pred_2   = performance_evaluation(test_data, test_labels, opt_var_2)

print(f"\n=== Method 2 Final Performance Analysis - Dataset {DATASET_NUM} (SPSA) ===")
print(f"Method 2 Final Training Accuracy: {final_train_acc_2:.4f}")
print(f"Method 2 Final Test Accuracy: {final_test_acc_2:.4f}")
print(f"Method 2 Final Cost: {opt_value_2:.6f}")
print(f"\nMethod 2 Training completed successfully!")
print(f"All Method 2 results saved in: {RESULTS_DIR}")
